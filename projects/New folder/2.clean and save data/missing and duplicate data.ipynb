# %%
import pandas as pd

# %%
# Generate a date range from the minimum to the maximum date in your data
full_range = pd.date_range(start=df['open_time'].min(), end=df['open_time'].max(), freq='1T')

# Create a DataFrame with the full range of time intervals
full_data = pd.DataFrame({'open_time': full_range})

# Merge the full range DataFrame with the original data using a left join
merged_data = pd.merge(full_data, df, on='open_time', how='left')

# Check for missing data
missing_data = merged_data[merged_data['open'].isnull()]

# Merge the full range DataFrame with the original data using a left join
merged_data = pd.merge(full_data, df, on='open_time', how='left')

# Check for missing data
missing_data = merged_data[merged_data['open'].isnull()]

print(missing_data)
